# %% [markdown]
# # Вступ
# Мене **звати** Катерина!
#
# Я вперше пишу код на *Python*!

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
777-666
# Out:
# 111

# %%
1+1
# Out:
# 2

# %%
# !pwd
# Out:
# /Users/Kate/Downloads

# %%
# !ls
# Out:
# (uakino.club)_vtryana-rka.torrent
# 131_4- Speakout Starter Workbook (with key)_2016, 2nd-Audio
# 131_4- Speakout Starter Workbook (with key)_2016, 2nd-Audio 2
# 2022-12-05T12-29 Операция #5407295662714177-10999666.pdf
# 409_1_Speakout_Starter_Student's_Book_2015,_2nd,_160p_1.pdf
# 409_3_Speakout_Starter_Workbook_with_key_2016,_2nd,_88p_2.PDF
# 409_4- Speakout Starter Workbook (with key)_2016, 2nd-Audio.zip
# Chia-1.7.0-arm64.dmg
# English File WB.pdf
# Opera Installer.app
# Sublime Text.app
# Wind River (2017) BDRip 1080p H.265 [4xUKR_ENG] [Hurtom].mkv
# Zoom.pkg
# boarding-pass (1).pdf
# boarding-pass.pdf
# googlechrome.dmg
# lecture_0_jupyter_demo (1).ipynb
# lecture_0_jupyter_demo.ipynb
# python-3.12.0-macos11.pkg
# receipt_7122150577.pdf
# sublime_text_build_4152_mac (1).zip
# sublime_text_build_4152_mac.zip
# untitled.txt
# как создать маркетинг стратегию.pdf
# чек-лист 100+ креативов.pdf
# крео.pdf
# Опрос клиентов Maribella.pptx
# Новый документ.pdf
# Анализ ЦА.xlsx
# ...

# %% [markdown]
# ## Розділ 1
# просто текст
#
# ### Підрозділ
#
# ## Розділ 2

# %%
import time

for i in range(10):
    print(i)
    time.sleep(30)

# %%
my_list = [1, 2, 3, 4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# В мене є список
# * Один
#     - підсписок
#         - це
#   - інший підписок
#         - то
#         - і ще то
# * два
#   - підсписок

# %%
[x**2 for x in range(-10, 11)]
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
s = 'Hello world!'

# %%
print(s)
# Out:
# Hello world!

# %%
1+1
print(2+22)
3+3
s
# Out:
# 24
# 'Hello world!'

# %%
a = 'Hello everyone!'

# %%
a
# Out:
# 'Hello everyone!'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(20)));

# %% [markdown]
# ## Розділ 3

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
a/b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 a/b
#
# NameError: name 'a' is not defined
